# %%
#!pip install crewai crewai_tools langchain langchain_community langchain_ollama streamlit duckduckgo-search

# %%
from crewai import LLM
from langchain_ollama.llms import OllamaLLM

llm = LLM(
    model="ollama/llama3.2",
    base_url="http://localhost:11434"
)

# %%
from crewai.tools import tool
from langchain_community.tools import DuckDuckGoSearchResults 
import json


@tool
def search_web_tool(query: str):
    """
    Searches the web and returns results.
    """
    search_tool = DuckDuckGoSearchResults(num_results=10, verbose=True)
    return search_tool.run(query)

# %%
from crewai import Agent

# Agent Resercher
guide_expert= Agent( 
    role="City Local Guide Expert",
    goal="Provides information on things to do in the city based on the user's interests.",
    backstory="""A local expert with a passion for sharing the best experiences and hidden gems of their city.""",
    tools=[search_web_tool],
    verbose=True,
    max_iter=5,
    llm=LLM(model="ollama/llama3.2",base_url="http://localhost:11434"),  #ChatOpenAI(temperature=0, model="gpt-4o-mini"),
    allow_delegation=False,
    )

# %%
# Agent city expert
location_expert = Agent(
    role="Travel Trip Expert",
    goal="Adapt to the user destination vity language (French if city in French Country. Gather helpful information about to the city and city during travel.",
    backstory="""A seasoned traveler who has explored various destinations and knows the ins and outs of travel logistics.""",
    tools=[search_web_tool],
    verbose=True,
    max_iter=5,
    llm=LLM(model="ollama/llama3.2",base_url="http://localhost:11434"),
    allow_delegation=False,
    )

# %%
planner_expert = Agent(
    role="Travel Planning Expert",
    goal="Compiles all gathered information to provide a comprehensive travel plan.",
    backstory="""
    You are a professional guide with a passion for travel.
    An organizational wizard who can turn a list of possibilities into a seamless itinerary.
    """,
    tools=[search_web_tool],
    verbose=True,
    max_iter=5,
    llm=LLM(model="ollama/llama3.2",base_url="http://localhost:11434"),
    allow_delegation=False,
    )

# %%
from datetime import datetime
from crewai import Task

from_city = "India"
destination_city = "Rome"
date_from = "1st March 2025"
date_to = "7th March 2025"
interests = "sight seeing and good food"

location_task = Task(
    description=f"""
    In French : This task involves a comprehensive data collection process to provide the traveler with essential information about their destination. It includes researching and compiling details on various accommodations, ranging from budget-friendly hostels to luxury hotels, as well as estimating the cost of living in the area. The task also covers transportation options, visa requirements, and any travel advisories that may be relevant.
    consider also the weather conditions forcast on the travel dates. and all the events that may be relevant to the traveler during the trip period.
    
    Traveling from : {from_city}
    Destination city : {destination_city}
    Arrival Date : {date_from}
    Departure Date : {date_to}

    Follow this rules : 
    1. if the {destination_city} is in a French country : Respond in FRENCH.
    """,
    expected_output=f"""
    if the {destination_city} is in a French country : Respond in FRENCH.
    In markdown format : A detailed markdown report that includes a curated list of recommended places to stay, a breakdown of daily living expenses, and practical travel tips to ensure a smooth journey.
    """,
    agent=location_expert,
    output_file='city_report.md',
)

# %%
guide_task = Task(
    description=f"""
    if the {destination_city} is in a French country : Respond in FRENCH.
    Tailored to the traveler's personal {interests}, this task focuses on creating an engaging and informative guide to the city's attractions. It involves identifying cultural landmarks, historical spots, entertainment venues, dining experiences, and outdoor activities that align with the user's preferences such {interests}. The guide also highlights seasonal events and festivals that might be of interest during the traveler's visit.
    Destination city : {destination_city}
    interests : {interests}
    Arrival Date : {date_from}
    Departure Date : {date_to}

    Follow this rules : 
    1. if the {destination_city} is in a French country : Respond in FRENCH.
    """,
    expected_output=f"""
    An interactive markdown report that presents a personalized itinerary of activities and attractions, complete with descriptions, locations, and any necessary reservations or tickets.
    """,

    agent=guide_expert,
    output_file='guide_report.md',
)

# %%
planner_task = Task(
    description=f"""
    This task synthesizes all collected information into a detaileds introduction to the city (description of city and presentation, in 3 pragraphes) cohesive and practical travel plan. and takes into account the traveler's schedule, preferences, and budget to draft a day-by-day itinerary. The planner also provides insights into the city's layout and transportation system to facilitate easy navigation.
    Destination city : {destination_city}
    interests : {interests}
    Arrival Date : {date_from}
    Departure Date : {date_to}

    Follow this rules : 
    1. if the {destination_city} is in a French country : Respond in FRENCH.
    """,
    expected_output="""
    if the {destination_city} is in a French country : Respond in FRENCH.
    A rich markdown document with emojis on each title and subtitle, that :
    In markdown format : 
    # Welcome to {destination_city} :
    A 4 paragraphes markdown formated including :
    - a curated articles of presentation of the city, 
    - a breakdown of daily living expenses, and spots to visit.
    # Here's your Travel Plan to {destination_city} :
    Outlines a daily detailed travel plan list with time allocations and details for each activity, along with an overview of the city's highlights based on the guide's recommendations
    """,
    context=[location_task, guide_task],
    #context=context,
    agent=planner_expert,
        output_file='travel_plan.md',
        )

# %%
# Task: Location
def location_task(agent, from_city, destination_city, date_from, date_to):
    return Task(
        description=f"""
        In French : This task involves a comprehensive data collection process to provide the traveler with essential information about their destination. It includes researching and compiling details on various accommodations, ranging from budget-friendly hostels to luxury hotels, as well as estimating the cost of living in the area. The task also covers transportation options, visa requirements, and any travel advisories that may be relevant.
        consider also the weather conditions forcast on the travel dates. and all the events that may be relevant to the traveler during the trip period.
        
        Traveling from : {from_city}
        Destination city : {destination_city}
        Arrival Date : {date_from}
        Departure Date : {date_to}

        Follow this rules : 
        1. if the {destination_city} is in a French country : Respond in FRENCH.
        """,
        expected_output=f"""
        if the {destination_city} is in a French country : Respond in FRENCH.
        In markdown format : A detailed markdown report that includes a curated list of recommended places to stay, a breakdown of daily living expenses, and practical travel tips to ensure a smooth journey.
        """,
        agent=agent,
        output_file='city_report.md',
    )

# Task: Location
def guide_task(agent, destination_city, interests, date_from, date_to):    
    return Task(
        description=f"""
        if the {destination_city} is in a French country : Respond in FRENCH.
        Tailored to the traveler's personal {interests}, this task focuses on creating an engaging and informative guide to the city's attractions. It involves identifying cultural landmarks, historical spots, entertainment venues, dining experiences, and outdoor activities that align with the user's preferences such {interests}. The guide also highlights seasonal events and festivals that might be of interest during the traveler's visit.
        Destination city : {destination_city}
        interests : {interests}
        Arrival Date : {date_from}
        Departure Date : {date_to}

        Follow this rules : 
        1. if the {destination_city} is in a French country : Respond in FRENCH.
        """,
        expected_output=f"""
        An interactive markdown report that presents a personalized itinerary of activities and attractions, complete with descriptions, locations, and any necessary reservations or tickets.
        """,

        agent=agent,
        output_file='guide_report.md',
    )


# Task: Planner
def planner_task(context, agent, destination_city, interests, date_from, date_to):
    return Task(
        description=f"""
        This task synthesizes all collected information into a detaileds introduction to the city (description of city and presentation, in 3 pragraphes) cohesive and practical travel plan. and takes into account the traveler's schedule, preferences, and budget to draft a day-by-day itinerary. The planner also provides insights into the city's layout and transportation system to facilitate easy navigation.
        Destination city : {destination_city}
        interests : {interests}
        Arrival Date : {date_from}
        Departure Date : {date_to}

        Follow this rules : 
        1. if the {destination_city} is in a French country : Respond in FRENCH.
        """,
        expected_output="""
        if the {destination_city} is in a French country : Respond in FRENCH.
        A rich markdown document with emojis on each title and subtitle, that :
        In markdown format : 
        # Welcome to {destination_city} :
        A 4 paragraphes markdown formated including :
        - a curated articles of presentation of the city, 
        - a breakdown of daily living expenses, and spots to visit.
        # Here's your Travel Plan to {destination_city} :
        Outlines a daily detailed travel plan list with time allocations and details for each activity, along with an overview of the city's highlights based on the guide's recommendations
        """,
        #context=[location_task, guide_task],
        context=context,
        agent=agent,
        output_file='travel_plan.md',
        )

# %%
location_task = location_task(
  location_expert,
  from_city,
  destination_city,
  date_from,
  date_to
)

guide_task = guide_task(
  guide_expert,
  destination_city,
  interests,
  date_from,
  date_to
)

planner_task = planner_task(
  [location_task, guide_task],
  planner_expert,
  destination_city,
  interests,
  date_from,
  date_to,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 location_task = location_task(
#       2   location_expert,
#       3   from_city,
#       4   destination_city,
#       5   date_from,
#       6   date_to
#       7 )
#       9 guide_task = guide_task(
#      10   guide_expert,
#      11   destination_city,
#    (...)     14   date_to
#      15 )
#      17 planner_task = planner_task(
#      18   [location_task, guide_task],
#      19   planner_expert,
#    (...)     23   date_to,
#      24 )
#
# TypeError: 'Task' object is not callable

# %%
from crewai import Crew, Process
crew = Crew(
agents=[location_expert, guide_expert, planner_expert],
tasks=[location_task, guide_task, planner_task],
process=Process.sequential,
full_output=True,
share_crew=False,
verbose=True
)

result = crew.kickoff()
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: d0ef08b3-8477-40ed-a1bb-64998b67c25f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name:                                                                                                          │
# │          In French : This task involves a comprehensive data collection process to provide the traveler with    │
# │  essential information about their destination. It includes researching and compiling details on various        │
# │  accommodations, ranging from budget-friendly hostels to luxury hotels, as well as estimating the cost of       │
# │  living in the area. The task also covers transportation options, visa requirements, and any travel advisories  │
# │  that may be relevant.                                                                                          │
# │          consider also the weather conditions forcast on the travel dates. and all the events that may be       │
# │  relevant to the traveler during the trip period.                                                               │
# │                                                                                                                 │
# │          Traveling from : India                                                                                 │
# │          Destination city : Rome                                                                                │
# │          Arrival Date : 1st March 2025                                                                          │
# │          Departure Date : 7th March 2025                                                                        │
# │                                                                                                                 │
# │          Follow this rules :                                                                                    │
# │          1. if the Rome is in a French country : Respond in FRENCH.                                             │
# │                                                                                                                 │
# │  ID: 8e2e1c45-6d74-415e-9e1b-d3338baaaca4                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Failure ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name:                                                                                                          │
# │          In French : This task involves a comprehensive data collection process to provide the traveler with    │
# │  essential information about their destination. It includes researching and compiling details on various        │
# │  accommodations, ranging from budget-friendly hostels to luxury hotels, as well as estimating the cost of       │
# │  living in the area. The task also covers transportation options, visa requirements, and any travel advisories  │
# │  that may be relevant.                                                                                          │
# │          consider also the weather conditions forcast on the travel dates. and all the events that may be       │
# │  relevant to the traveler during the trip period.                                                               │
# │                                                                                                                 │
# │          Traveling from : India                                                                                 │
# │          Destination city : Rome                                                                                │
# │          Arrival Date : 1st March 2025                                                                          │
# │          Departure Date : 7th March 2025                                                                        │
# │                                                                                                                 │
# │          Follow this rules :                                                                                    │
# │          1. if the Rome is in a French country : Respond in FRENCH.                                             │
# │                                                                                                                 │
# │  Agent: Travel Trip Expert                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: d0ef08b3-8477-40ed-a1bb-64998b67c25f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 11
#       1 from crewai import Crew, Process
#       2 crew = Crew(
#       3 agents=[location_expert, guide_expert, planner_expert],
#       4 tasks=[location_task, guide_task, planner_task],
#    (...)      8 verbose=True
#       9 )
# ---> 11 result = crew.kickoff()
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\crew.py:1024, in Crew.kickoff(self, inputs, input_files, from_checkpoint)
#    1021 inputs = prepare_kickoff(self, inputs, input_files)
#    1023 if self.process == Process.sequential:
# -> 1024     result = self._run_sequential_process()
#    1025 elif self.process == Process.hierarchical:
#    1026     result = self._run_hierarchical_process()
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\crew.py:1473, in Crew._run_sequential_process(self)
#    1471 def _run_sequential_process(self) -> CrewOutput:
#    1472     """Executes tasks sequentially and returns the final output."""
# -> 1473     return self._execute_tasks(self.tasks)
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\crew.py:1572, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#    1569     futures.clear()
#    1571 context = self._get_context(task, task_outputs)
# -> 1572 task_output = task.execute_sync(
#    1573     agent=exec_data.agent,
#    1574     context=context,
#    1575     tools=exec_data.tools,
#    1576 )
#    1577 task_outputs.append(task_output)
#    1578 self._process_task_result(task, task_output)
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\task.py:580, in Task.execute_sync(self, agent, context, tools)
#     578 """Execute the task synchronously."""
#     579 self.start_time = datetime.datetime.now()
# --> 580 return self._execute_core(agent, context, tools)
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\task.py:882, in Task._execute_core(self, agent, context, tools)
#     880     self.end_time = datetime.datetime.now()
#     881     crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))
# --> 882     raise e
#     883 finally:
#     884     clear_task_files(self.id)
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\task.py:790, in Task._execute_core(self, agent, context, tools)
#     784 if not (
#     785     executor and executor._resuming and resume_task_scope(str(self.id))
#     786 ):
#     787     crewai_event_bus.emit(
#     788         self, TaskStartedEvent(context=context, task=self)
#     789     )
# --> 790 result = agent.execute_task(
#     791     task=self,
#     792     context=context,
#     793     tools=tools,
#     794 )
#     796 self._post_agent_execution(agent)
#     798 if isinstance(result, BaseModel):
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\agent\core.py:807, in Agent.execute_task(self, task, context, tools)
#     805     raise e
#     806 except Exception as e:
# --> 807     result = self._handle_execution_error(e, task, context, tools)
#     809 return self._finalize_task_execution(task, result)
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\agent\core.py:691, in Agent._handle_execution_error(self, e, task, context, tools)
#     673 def _handle_execution_error(
#     674     self,
#     675     e: Exception,
#    (...)    678     tools: list[BaseTool] | None,
#     679 ) -> Any:
#     680     """Handle execution errors with retry logic (sync path).
#     681
#     682     Args:
#    (...)    689         Result from retried execution.
#     690     """
# --> 691     self._check_execution_error(e, task)
#     692     return self.execute_task(task, context, tools)
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\agent\core.py:671, in Agent._check_execution_error(self, e, task)
#     662 if self._times_executed > self.max_retry_limit:
#     663     crewai_event_bus.emit(
#     664         self,
#     665         event=AgentExecutionErrorEvent(
#    (...)    669         ),
#     670     )
# --> 671     raise e
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\agent\core.py:794, in Agent.execute_task(self, task, context, tools)
#     790         result = self._execute_with_timeout(
#     791             task_prompt, task, self.max_execution_time
#     792         )
#     793     else:
# --> 794         result = self._execute_without_timeout(task_prompt, task)
#     796 except TimeoutError as e:
#     797     crewai_event_bus.emit(
#     798         self,
#     799         event=AgentExecutionErrorEvent(
#    (...)    803         ),
#     804     )
#
# File D:\Program Files\anaconda3\Lib\site-packages\crewai\agent\core.py:869, in Agent._execute_without_timeout(self, task_prompt, task)
#     867 if inspect.isawaitable(invoke_result):
#     868     invoke_result.close()
# --> 869     raise RuntimeError(
#     870         "Agent execution was invoked synchronously from within a running "
#     871         "event loop. Use `agent.kickoff_async()` / `crew.kickoff_async()` "
#     872         "(or `await agent.aexecute_task(...)`) when calling from async code."
#     873     )
#     874 return invoke_result["output"]
#
# RuntimeError: Agent execution was invoked synchronously from within a running event loop. Use `agent.kickoff_async()` / `crew.kickoff_async()` (or `await agent.aexecute_task(...)`) when calling from async code.
